# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as datetime

# %%
#helper function used in plotting the graphs
#x for value on x axis
#y for value on y axis
#hue data being plotted in relation to x or y
#i how many  value appear in the bargraph
def cat_sum(dataframe, x=None, y=None, hue=None, palette='Set1',i=None,verbose=True):
    if x == None:
        column_interested = y
    else:
        column_interested = x
    series = dataframe[column_interested]
    print(series.describe())
    print('mode: ', series.mode())
    if verbose:
        print('='*80)
        print(series.value_counts())
        
        #plot the bargraph according to the input x or y value 
        if x != None:
            sns.countplot(x=x, y=y, hue=hue, data=dataframe, palette=palette,
            order=df2[x].value_counts().iloc[:i].index)
        else:
            sns.countplot(x=x, y=y, hue=hue, data=dataframe, palette=palette,
            order=df2[y].value_counts().iloc[:i].index)

    plt.show()

# %%
df = pd.read_csv('MPsProfileInformation10thParliament.csv')

# %%
pd.set_option('display.max_rows', 60)

# %%
df2 = df.copy()
df2
df2.set_index('No.')
# Out:
#                          Name of M.P   District  \
# No.
# 1                 Aadroa Alex Onzima       None
# 2                      Ababiku Jesca   Adjumani
# 3    ABACANON CHARLES ANGIRO GUTOMOI       Lira
# 4                        ABALA DAVID      Ngora
# 5               ABBAS AGABA MUGISHA    Kamwenge
# ..                               ...        ...
# 435            Wekomba Nambozo Sarah  Bulambuli
# 436         Werikhe Kafabusa Michael      Mbale
# 437                    Woboya Vicent    Sironko
# 438               Yaguma Wilberforce    Mbarara
# 439                    Zaake Francis    Mityana
#
#                       Constituency Political Party       Profession  \
# No.
# 1                       Ex-Officio            None    Administrator
# 2    District Woman Representative             NRM          Teacher
# 3               ERUTE COUNTY NORTH             FDC           Farmer
# 4                     Ngora County             NRM    Administrator
# ...

# %%
df2.head()
# Out:
#    No.                      Name of M.P  District  \
# 0    1               Aadroa Alex Onzima      None
# 1    2                    Ababiku Jesca  Adjumani
# 2    3  ABACANON CHARLES ANGIRO GUTOMOI      Lira
# 3    4                      ABALA DAVID     Ngora
# 4    5             ABBAS AGABA MUGISHA   Kamwenge
#
#                     Constituency Political Party       Profession  \
# 0                     Ex-Officio            None    Administrator
# 1  District Woman Representative             NRM          Teacher
# 2             ERUTE COUNTY NORTH             FDC           Farmer
# 3                   Ngora County             NRM    Administrator
# 4              Kitagwenda County             NRM  Lawyer/Advocate
#
#   Marital status                 Phone number Date of Birth  \
# 0        Married  +256772411334/+256794336266    06-24-1952
# 1         Single                    772315541    07/17/1975
# 2        Married                    392944775    05-17-1949
# ...

# %%
df2.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 434    False
# 435    False
# 436    False
# 437    False
# 438    False
# Length: 439, dtype: bool

# %% [markdown]
# Dropping all excess columns that were empty and replacing 'NaN' cells with empty strings ''

# %%
#Dropping all excess columns that were empty and replacing 'NaN' cells with empty strings ''
df.columns.str.match('Unnamed')
df2 = df.loc[:,~df.columns.str.match('Unnamed')]
df2.fillna('',inplace=True)
df2
# Out:
#      No.                      Name of M.P   District  \
# 0      1               Aadroa Alex Onzima       None
# 1      2                    Ababiku Jesca   Adjumani
# 2      3  ABACANON CHARLES ANGIRO GUTOMOI       Lira
# 3      4                      ABALA DAVID      Ngora
# 4      5             ABBAS AGABA MUGISHA    Kamwenge
# ..   ...                              ...        ...
# 434  435            Wekomba Nambozo Sarah  Bulambuli
# 435  436         Werikhe Kafabusa Michael      Mbale
# 436  437                    Woboya Vicent    Sironko
# 437  438               Yaguma Wilberforce    Mbarara
# 438  439                    Zaake Francis    Mityana
#
#                       Constituency Political Party       Profession  \
# 0                       Ex-Officio            None    Administrator
# 1    District Woman Representative             NRM          Teacher
# 2               ERUTE COUNTY NORTH             FDC           Farmer
# ...

# %% [markdown]
# Cleaning dates and converting to proper date time format

# %%
# df2[['Date of Birth','P.L.E Year','U.C.E Year','U.A.C.E Year','Year of first Degree','Year of second degree','Year of Third Degree']]
# df2.loc[df2['Date of Birth'] == '07/071983']
# df2.loc[df2['Date of Birth'] == '09/0/1971']
df2['Date of Birth'] = df2['Date of Birth'].replace(['07/071983'],'07/07/1983')
df2['Date of Birth'] = df2['Date of Birth'].replace(['09/0/1971'],'09/01/1971')
# replace those dates with a proper date to avoid errors
df2['Date of Birth'] = pd.to_datetime(df2['Date of Birth'])
#condition to select dates less than current time eg 2056
mask = df2['Date of Birth'] <= datetime.datetime.now()
df2 = df2.loc[mask]
df2[['Date of Birth','P.L.E Year','U.C.E Year','U.A.C.E Year','Year of first Degree','Year of second degree','Year of Third Degree']].head(10)
# Out:
#    Date of Birth P.L.E Year U.C.E Year U.A.C.E Year Year of first Degree  \
# 0     1952-06-24       1969                                         2005
# 1     1975-07-17       1990       1994         1997                 2006
# 2     1949-05-17       1966       1972         1974
# 3     1975-10-03                                                    2000
# 4     1979-10-13                  1997         1999                 2004
# 5     1975-05-24                               1995                 2002
# 7     1964-08-25       1979       1983         1989
# 9     1983-07-07       1996       2001
# 10    1970-12-27             1987-1990    1990-1992            1993-1996
# 12    1968-09-26
#
#    Year of second degree Year of Third Degree
# 0
# 1                   2013
# 2
# 3                   2008
# 4                   2009                 2011
# 5                   2006                 2013
# 7
# 9
# 10                  1997
# 12

# %% [markdown]
# Changing columns which have values with uneven cases to capitalized eg **DATa analySiS** to **Data Analysis**
# and stripping all trailing whitespace

# %%
df2['Name of M.P']= df2['Name of M.P'].str.strip().str.title()
df2['District']= df2['District'].str.strip().str.title()
df2['Constituency'] = df2['Constituency'].str.strip().str.title()
df2['Political Party']= df2['Political Party'].str.strip().str.title()
df2['Profession'] = df2['Profession'].str.strip().str.title()
df2['Marital status'] = df2['Marital status'].str.strip().str.title()
df2['U.C.E School'] = df2['U.C.E School'].str.strip().str.title()
df2['U.A.C.E School'] = df2['U.A.C.E School'].str.strip().str.title()
df2['First Degree'] = df2['First Degree'].str.strip().str.title()
df2['University of First Degree'] = df2['University of First Degree'].str.strip().str.title()
df2['Second Degree'] = df2['Second Degree'].str.strip().str.title()
df2['University of Second Degree'] = df2['University of Second Degree'].str.strip().str.title()
df2['Third Degree'] = df2['Third Degree'].str.strip().str.title()
df2['University of Third Degree'] = df2['University of Third Degree'].str.strip().str.title()
df2['Other Qualifications'] = df2['Other Qualifications'].str.strip().str.title()
df2['Past Job_1'] = df2['Past Job_1'].str.strip().str.title()
df2['Past Job_2'] = df2['Past Job_2'].str.strip().str.title()
df2['Past Job_3'] = df2['Past Job_3'].str.strip().str.title()
df2['Past Job_4'] = df2['Past Job_4'].str.strip().str.title()
df2['Past Job_5'] = df2['Past Job_5'].str.strip().str.title()
df2['Past Job_6'] = df2['Past Job_6'].str.strip().str.title()
df2['Past Job_7'] = df2['Past Job_7'].str.strip().str.title()
df2['Past Job_8'] = df2['Past Job_8'].str.strip().str.title()
df2['Past Job_9'] = df2['Past Job_9'].str.strip().str.title()
df2['Past Job_10'] = df2['Past Job_10'].str.strip().str.title()
df2['Hobbies'] = df2['Hobbies'].str.strip().str.title()
df2['Special Interests'] = df2['Special Interests'].str.strip().str.title()
df2['Other Information'] = df2['Other Information'].str.strip().str.title()
df2['Professional Body Membership'] = df2['Professional Body Membership'].str.strip().str.title()
df2['Committee_1'] = df2['Committee_1'].str.strip().str.title()
df2['Role on Committee 1'] = df2['Role on Committee 1'].str.strip().str.title()
df2['Committee_2'] = df2['Committee_2'].str.strip().str.title()
df2['Role on Committee 2'] = df2['Role on Committee 2'].str.strip().str.title()
df2['Committee_3'] = df2['Committee_3'].str.strip().str.title()
df2['Role on Committee 3'] = df2['Role on Committee 3'].str.strip().str.title()
df2['Committee_4'] = df2['Committee_4'].str.strip().str.title()
df2['Role on Committee 4'] = df2['Role on Committee 4'].str.strip().str.title()
df2
# Out:
#      No.                      Name of M.P   District  \
# 0      1               Aadroa Alex Onzima       None
# 1      2                    Ababiku Jesca   Adjumani
# 2      3  Abacanon Charles Angiro Gutomoi       Lira
# 3      4                      Abala David      Ngora
# 4      5              Abbas Agaba Mugisha   Kamwenge
# ..   ...                              ...        ...
# 433  434       Watenga Nabutanyi Godffrey     Bududa
# 434  435            Wekomba Nambozo Sarah  Bulambuli
# 435  436         Werikhe Kafabusa Michael      Mbale
# 437  438               Yaguma Wilberforce    Mbarara
# 438  439                    Zaake Francis    Mityana
#
#                       Constituency Political Party       Profession  \
# 0                       Ex-Officio            None    Administrator
# 1    District Woman Representative             Nrm          Teacher
# 2               Erute County North             Fdc           Farmer
# ...

# %% [markdown]
# Converting all political parties with **None** to **Independent**

# %%
# replace all None political parties with Independent
df2["Political Party"].replace({"None": "Independent"}, inplace=True)
df2['Political Party']
# Out:
# 0      Independent
# 1              Nrm
# 2              Fdc
# 3              Nrm
# 4              Nrm
#           ...
# 433    Independent
# 434    Independent
# 435            Nrm
# 437            Nrm
# 438    Independent
# Name: Political Party, Length: 352, dtype: object

# %% [markdown]
# This function filters out oddities in the Marital status column eg **row 108 had phone numbers**

# %%
#This function filters out oddities in the Marital status column eg row 108 had phone numbers
def filter_rows_by_values(df, col, values):
    return df[df[col].isin(values) == True]
df2 = filter_rows_by_values(df2, 'Marital status',['Married','Single','Widowed','Divorced'])

# %%
#plotting district with respect to political party
cat_sum(df2, x = 'District',hue ='Political Party', i= 4)
# Out:
# count      346
# unique     117
# top       None
# freq        12
# Name: District, dtype: object
# mode:  0    None
# dtype: object
# ...
# None                   12
# Kampala                 8
# Updf Representative     7
# Kabale                  7
# Mubende                 6
#                        ..
# Abim                    1
# Napak                   1
# Lamwo                   1
# Kamuli                  1
# Ibanda                  1
# Name: District, Length: 117, dtype: int64

# %%
#plotting district with respect to marital status
cat_sum(df2, x = 'District', hue ='Marital status', i=4)
# Out:
# count      346
# unique     117
# top       None
# freq        12
# Name: District, dtype: object
# mode:  0    None
# dtype: object
# ...
# None                   12
# Kampala                 8
# Updf Representative     7
# Kabale                  7
# Mubende                 6
#                        ..
# Abim                    1
# Napak                   1
# Lamwo                   1
# Kamuli                  1
# Ibanda                  1
# Name: District, Length: 117, dtype: int64

# %%
#plotting constituency with respect to political party
cat_sum(df2, x = 'Constituency', hue ='Political Party',i=4)
# Out:
# count                               346
# unique                              234
# top       District Woman Representative
# freq                                 85
# Name: Constituency, dtype: object
# mode:  0    District Woman Representative
# dtype: object
# ...
# District Woman Representative    85
# Ex-Officio                       12
# Updf Representative               7
# Eastern                           3
# Ntoroko County                    2
#                                  ..
# Bunyole East County               1
# Dokolo South County               1
# Mukono County South               1
# Bukanga County                    1
# Kole North County                 1
# Name: Constituency, Length: 234, dtype: int64

# %%
#plotting profession with respect to marital status
cat_sum(df2, x='Profession', hue='Marital status', i =5)
# Out:
# count         346
# unique         68
# top       Teacher
# freq           49
# Name: Profession, dtype: object
# mode:  0    Teacher
# dtype: object
# ...
# Teacher            49
# Social Worker      41
# Administrator      30
# Accountant         29
# Politician         20
#                    ..
# Artist Fine Art     1
# Sportsman           1
# Public Health       1
# Analyst             1
# Artist Drama        1
# Name: Profession, Length: 68, dtype: int64

# %%
#plotting constituency with respect to political party
cat_sum(df2, x='Constituency',hue='Political Party', i=4)
# Out:
# count                               346
# unique                              234
# top       District Woman Representative
# freq                                 85
# Name: Constituency, dtype: object
# mode:  0    District Woman Representative
# dtype: object
# ...
# District Woman Representative    85
# Ex-Officio                       12
# Updf Representative               7
# Eastern                           3
# Ntoroko County                    2
#                                  ..
# Bunyole East County               1
# Dokolo South County               1
# Mukono County South               1
# Bukanga County                    1
# Kole North County                 1
# Name: Constituency, Length: 234, dtype: int64

# %%
#plotting date of birth with respect to political party
cat_sum(df2, x='Date of Birth',hue='Political Party', i=3)
# Out:
# count                     346
# unique                    339
# top       1973-11-23 00:00:00
# freq                        2
# first     1940-02-29 00:00:00
# last      1994-12-15 00:00:00
# Name: Date of Birth, dtype: object
# mode:  0   1958-11-28
# 1   1962-08-30
# 2   1963-06-26
# 3   1973-11-23
# 4   1974-04-04
# 5   1976-12-05
# 6   1982-11-23
# dtype: datetime64[ns]
# ...
# 1973-11-23    2
# 1958-11-28    2
# 1963-06-26    2
# 1982-11-23    2
# 1976-12-05    2
#              ..
# 1975-10-03    1
# 1982-10-10    1
# 1979-10-21    1
# 1976-01-04    1
# 1972-05-15    1
# Name: Date of Birth, Length: 339, dtype: int64

# %%
# def label_function(val):
#     return f'{val / 100 * len(df):.0f}\n{val:.0f}%'

def pie(pie1 =None , pie2=None, data= None ):
    # N = 50
    df = data

    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 8))

    df.groupby(pie1).size().plot(kind='pie', autopct=label_function, textprops={'fontsize': 12}, ax=ax1)
    df.groupby(pie2).size().plot(kind='pie', autopct=label_function, textprops={'fontsize': 12}, ax=ax2)
    ax1.set_xlabel('Per  '+ pie1 , size=18)
    ax2.set_xlabel('Per ' + pie2, size=18)
    plt.tight_layout()
    plt.show()

# %%
pie(pie1='Marital status', pie2='Political Party', data=df2)

# %%
pie(pie1='Date of Birth', pie2='', data=df2)
